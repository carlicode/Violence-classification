# %%
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display
import IPython.display as ipd

# %%
cry_wav = "C:/Users/Carlita/Desktop/tesis/Experiment 1 chunks/crying/freesound_crying_1.wav"

# %%
cry_wav, sr = librosa.load(cry_wav)

# %%
FRAME_SIZE = 1024
HOP_LENGTH = 512

# %% [markdown]
# #Root-mean-squared energy with Librosa

# %%
rms_cry_wav = librosa.feature.rms(cry_wav, frame_length=FRAME_SIZE, hop_length=HOP_LENGTH)[0]
# Out:
# C:\Users\Carlita\AppData\Local\Temp\ipykernel_6012\41259899.py:1: FutureWarning: Pass y=[ 5.6532444e-05  7.3790827e-05  3.4670455e-05 ... -7.9952995e-04
#  -7.8520342e-04 -8.4552396e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rms_cry_wav = librosa.feature.rms(cry_wav, frame_length=FRAME_SIZE, hop_length=HOP_LENGTH)[0]

# %% [markdown]
# #Visualise RMSE + waveform

# %%
frames = range(len(rms_cry_wav))
t = librosa.frames_to_time(frames, hop_length=HOP_LENGTH)

# %%
plt.figure(figsize=(15, 10))
librosa.display.waveshow(cry_wav,alpha=0.5)
plt.plot(t, rms_cry_wav, color="r")
plt.ylim((-1, 1))
plt.title("cry_wav")
plt.show()
